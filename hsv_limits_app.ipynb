# %%
# A Software to isolate images and get their hsv lower and higher limits
#reference: https://stackoverflow.com/questions/10948589/choosing-the-correct-upper-and-lower-hsv-boundaries-for-color-detection-withcv

import cv2
import numpy as np

def nothing(x):
    pass

# Load image
image = cv2.imread('more_images/r.jpg')

# Create a window
cv2.namedWindow('image')

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing)
cv2.createTrackbar('SMin', 'image', 0, 255, nothing)
cv2.createTrackbar('VMin', 'image', 0, 255, nothing)
cv2.createTrackbar('HMax', 'image', 0, 179, nothing)
cv2.createTrackbar('SMax', 'image', 0, 255, nothing)
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):
    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display result image
    cv2.imshow('image', result)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 81 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 82 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 83 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 92 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 93 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 94 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 95 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 85 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 40 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 56, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 60, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 62, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 64, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 65, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 66, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 68, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 69, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 70, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 72, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 75, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 78, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 79, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 80, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 81, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 82, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 84, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 87, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 88, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 89, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 90, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 91, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 92, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 93, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 94, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 95, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 96, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 95, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 90, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 87, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 85, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 84, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 83, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 82, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 80, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 79, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 76, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 75, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 72, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 70, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 68, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 46), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 50), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 54), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 57), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 58), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 59), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 63), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 82), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 83), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 84), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 85), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 86), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 85), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 84), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 82), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 81), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 75), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 71), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 89), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 110), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 118), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 120), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 127), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 129), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 130), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 129), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 126), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 122), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 111), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 96), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 89), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 88), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 87), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 85), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 84), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 83), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 46), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 41), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 40), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 39), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 37), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 11), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 7), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 6), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 7), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 8), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 9), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 28), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 31), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 32), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 67, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 64, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 58, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 54, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 51, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 47, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 46, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 44, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 42, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 41, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 39, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 38, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 36, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 35, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 33, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 31, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 29, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 28, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 27, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 26, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 25, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 24, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 23, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 21, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 20, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 23, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 26, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 28, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 30, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 33, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 36, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 39, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 40, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 41, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 43, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 44, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 46, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 47, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 53 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 54 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 56 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 58 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 43), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 81), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 83), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 87), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 96), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 128 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 123 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 125 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 144 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 147 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 148 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 150 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 154 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 156 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 158 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 163 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 252, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 245, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 242, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 240, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 239, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 238, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 237, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 236, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 235, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 234, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 233, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 232, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 229, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 223, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 221, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 218, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 216, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 214, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 213, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 210, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 209, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 207, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 204, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 202, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 199, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 198, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 196, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 192, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 190, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 189, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 188, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 187, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 186, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 187, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 188, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 190, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 191, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 192, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 193, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 194, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 195, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 196, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 197, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 198, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 199, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 200, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 201, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 202, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 203, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 204, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 205, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 206, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 207, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 208, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 209, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 210, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 255)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 241)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 237)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 234)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 232)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 231)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 230)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 229)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 226)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 224)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 218)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 215)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 211)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 208)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 205)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 202)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 201)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 198)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 196)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 189)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 184)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 181)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 176)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 174)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 172)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 170)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 169)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 167)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 166)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 165)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 164)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 163)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 162)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 161)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 162)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 163)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 164)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 165)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 166)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 167)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 166)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 165)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 164)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 163)
# (hMin = 13 , sMin = 48, vMin = 98), (hMax = 179 , sMax = 211, vMax = 162)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 64
#      62     # Display result image
#      63     cv2.imshow('image', result)
# ---> 64     if cv2.waitKey(10) & 0xFF == ord('q'):
#      65         break
#      67 cv2.destroyAllWindows()
#
# KeyboardInterrupt:
